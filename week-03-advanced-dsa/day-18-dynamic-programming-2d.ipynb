# %% [markdown]
# # Day 18: Dynamic Programming 2D
#
# **Week 3 — Advanced DSA**
#
# ---
#
# ## 📚 Theory
#
# 2D DP problems usually involve a grid or two strings.
# State: `dp[i][j]`.
# Common patterns: Longest Common Subsequence, Edit Distance, Grid Traversal.

# %% [markdown]
# ## 🔨 Practice Problems

# %% [markdown]
# ### Problem 1: Longest Common Subsequence
#
# Return the length of their longest common subsequence.

# %%
class Solution:
    def longestCommonSubsequence(self, text1: str, text2: str) -> int:
        pass

# %% [markdown]
# ## 📝 Day 18 Review
#
# - [ ] Understand the core concepts of today's theory
# - [ ] Complete all practice problems
# - [ ] Review optimal solutions and time/space complexities
