# %% [markdown]
# # Day 17: Dynamic Programming 1D
#
# **Week 3 — Advanced DSA**
#
# ---
#
# ## 📚 Theory
#
# Dynamic Programming = Recursion + Memoization.
# Break a problem down into overlapping subproblems.
# Identify the state variables and the transition function.

# %% [markdown]
# ## 🔨 Practice Problems

# %% [markdown]
# ### Problem 1: Climbing Stairs
#
# How many distinct ways can you climb to the top?

# %%
class Solution:
    def climbStairs(self, n: int) -> int:
        pass

# %% [markdown]
# ### Problem 2: Coin Change
#
# Return the fewest number of coins that you need to make up that amount.

# %%
class Solution:
    def coinChange(self, coins: list[int], amount: int) -> int:
        pass

# %% [markdown]
# ## 📝 Day 17 Review
#
# - [ ] Understand the core concepts of today's theory
# - [ ] Complete all practice problems
# - [ ] Review optimal solutions and time/space complexities
