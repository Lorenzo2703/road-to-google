# %% [markdown]
# # Day 19: Tries and Advanced Strings
#
# **Week 3 — Advanced DSA**
#
# ---
#
# ## 📚 Theory
#
# Trie (Prefix Tree) is an efficient information retrieval data structure.
# O(M) time complexity for search, where M is the key length.

# %% [markdown]
# ## 🔨 Practice Problems

# %% [markdown]
# ### Problem 1: Implement Trie (Prefix Tree)
#
# Implement the Trie class.

# %%
class Trie:
    def __init__(self):
        pass
    def insert(self, word: str) -> None:
        pass
    def search(self, word: str) -> bool:
        pass
    def startsWith(self, prefix: str) -> bool:
        pass

# %% [markdown]
# ## 📝 Day 19 Review
#
# - [ ] Understand the core concepts of today's theory
# - [ ] Complete all practice problems
# - [ ] Review optimal solutions and time/space complexities
