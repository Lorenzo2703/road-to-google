# %% [markdown]
# # Day 21: Review & Mock (Week 3)
#
# **Week 3 — Advanced DSA**
#
# ---
#
# ## 📚 Theory
#
# Review Week 3 concepts: Graphs, DP, Tries, Greedy.
# Perform a 45-minute timed mock interview.

# %% [markdown]
# ## 🔨 Practice Problems

# %% [markdown]
# ### Problem 1: Course Schedule
#
# Determine if you can finish all courses (Topological Sort).

# %%
class Solution:
    def canFinish(self, numCourses: int, prerequisites: list[list[int]]) -> bool:
        pass

# %% [markdown]
# ## 📝 Day 21 Review
#
# - [ ] Understand the core concepts of today's theory
# - [ ] Complete all practice problems
# - [ ] Review optimal solutions and time/space complexities
