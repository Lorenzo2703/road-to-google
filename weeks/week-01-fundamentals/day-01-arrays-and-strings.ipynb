# %% [markdown]
# # Day 01: Arrays and Strings
#
# **Week 1 — DSA Foundations**
#
# ---
#
# ## 📚 Theory
#
# ### Arrays
# An array is a contiguous block of memory storing elements of the same type. In Python, `list` acts as a dynamic array.
#
# | Operation | Time Complexity | Notes |
# |-----------|----------------|-------|
# | Access by index | O(1) | Direct memory addressing |
# | Search (unsorted) | O(n) | Must check every element |
# | Insert at end | O(1) amortized | Resizing takes O(n) occasionally |
# | Insert/Delete at index | O(n) | Elements must be shifted |
#
# ### Key Patterns for Arrays
# 1. **Prefix Sum**: Precompute cumulative sums to answer range queries in O(1).
# 2. **Kadane's Algorithm**: Find maximum subarray sum in O(n).
# 3. **Two Pointers**: Often used when the array is sorted (more on this on Day 03).
# 4. **In-place Modification**: Modify array without extra space (Google highly values space efficiency).
#
# ### Strings in Python
# - Strings are **immutable** — every modification (like concatenation) creates a new string.
# - Use `list(s)` to convert for in-place modifications, then `''.join(lst)`.
# - String comparison is `O(min(n, m))` where `n` and `m` are the lengths.
# - Common operations: `split()`, `strip()`, `lower()`, `replace()`, `find()`.
#
# ### 💡 Tips for Google Interviews
# - Always clarify constraints: Is the array sorted? Are there duplicates? What about empty inputs or negative numbers?
# - Always state the brute force solution quickly, then optimize.
# - Consider HashMaps to trade space for time (e.g., turning an O(n²) search into O(n)).

# %% [markdown]
# ## 🔨 Practice Problem 1: Two Sum (Easy)
#
# **LeetCode #1** | [Link](https://leetcode.com/problems/two-sum/)
#
# **Why it's relevant**: The most fundamental problem. Tests basic HashMap usage.
#
# **Problem**: Given an array of integers `nums` and an integer `target`, return indices of the two numbers that add up to `target`.
#
# **Approach**:
# 1. Brute force: O(n²) — check every pair.
# 2. Optimal: O(n) — use a HashMap to store the numbers seen so far and their indices.
#
# **Common pitfalls**:
# - Using the same element twice.
# - Not handling negative numbers.

# %%
def two_sum(nums: list[int], target: int) -> list[int]:
    """Return indices of two numbers that add up to target."""
    # time complexity: O(n), space complexity: O(n)
    
    seen={}
    for i in range(len(nums)):
        complement = target-nums[i]
        if complement in seen:
            return [seen[complement],i]
        else:
            seen[nums[i]]=i

    return [] 

# Test cases
assert two_sum([2, 7, 11, 15], 9) == [0, 1]
assert two_sum([3, 2, 4], 6) == [1, 2]
assert two_sum([3, 3], 6) == [0, 1]
print("All tests passed! ✅")
# Out:
# All tests passed! ✅

# %%
# Solution: Two Sum
def two_sum_solution(nums: list[int], target: int) -> list[int]:
    """O(n) time, O(n) space using HashMap."""
    seen = {}  # value -> index
    for i, num in enumerate(nums):
        complement = target - num
        if complement in seen:
            return [seen[complement], i]
        seen[num] = i
    return []

# %% [markdown]
# ## 🔨 Practice Problem 2: Valid Anagram (Easy)
#
# **LeetCode #242** | [Link](https://leetcode.com/problems/valid-anagram/)
#
# **Why it's relevant**: Tests frequency counting — a core pattern for strings.
#
# **Problem**: Given two strings `s` and `t`, return `true` if `t` is an anagram of `s`.
#
# **Approach**:
# 1. Sort both strings and compare: O(n log n).
# 2. Frequency count with HashMap or fixed array: O(n).
#
# **Common pitfalls**:
# - Not handling strings of different lengths.
# - Unicode character constraints vs standard ASCII.

# %%
def is_anagram(s: str, t: str) -> bool:
    """Return True if t is an anagram of s."""
    # YOUR SOLUTION HERE
    pass

# Test cases
assert is_anagram("anagram", "nagaram") == True
assert is_anagram("rat", "car") == False
assert is_anagram("", "") == True
print("All tests passed! ✅")

# %%
# Solution: Valid Anagram
from collections import Counter

def is_anagram_solution(s: str, t: str) -> bool:
    """O(n) time, O(1) space (26 chars max)."""
    if len(s) != len(t):
        return False
    return Counter(s) == Counter(t)

# %% [markdown]
# ## 🔨 Practice Problem 3: Product of Array Except Self (Medium)
#
# **LeetCode #238** | [Link](https://leetcode.com/problems/product-of-array-except-self/)
#
# **Why it's relevant**: Top Google question. Tests prefix/suffix products without division.
#
# **Problem**: Given array `nums`, return an array `answer` where `answer[i]` is the product of all elements except `nums[i]`. **You must NOT use division.**
#
# **Approach**:
# 1. Use two passes: calculate prefix products from left, then multiply by suffix products from right.
# 2. O(n) time, O(1) extra space (output array doesn't count).
#
# **Common pitfalls**:
# - Falling back to division.
# - Off-by-one errors when tracking prefixes.
# - Mishandling zeros.

# %%
def product_except_self(nums: list[int]) -> list[int]:
    """Return product of all elements except self, without division."""
    # YOUR SOLUTION HERE
    pass

# Test cases
assert product_except_self([1, 2, 3, 4]) == [24, 12, 8, 6]
assert product_except_self([-1, 1, 0, -3, 3]) == [0, 0, 9, 0, 0]
print("All tests passed! ✅")

# %%
# Solution: Product of Array Except Self
def product_except_self_solution(nums: list[int]) -> list[int]:
    """O(n) time, O(1) extra space."""
    n = len(nums)
    result = [1] * n
    
    prefix = 1
    for i in range(n):
        result[i] = prefix
        prefix *= nums[i]
    
    suffix = 1
    for i in range(n - 1, -1, -1):
        result[i] *= suffix
        suffix *= nums[i]
    
    return result

# %% [markdown]
# ## 🏆 Daily Challenge
#
# Without looking at the solutions above, solve the following:
#
# **Challenge**: Given an array of integers `nums`, find the length of the longest subarray where all elements are distinct.
#
# **Example**: `[1, 2, 3, 1, 2, 3]` → `3` (subarray `[1, 2, 3]`)
#
# **Hint**: This combines the Sliding Window pattern (coming soon) + Hash Sets.

# %%
def longest_distinct_subarray(nums: list[int]) -> int:
    """Find length of longest subarray with all distinct elements."""
    # YOUR SOLUTION HERE
    pass

# Test cases
assert longest_distinct_subarray([1, 2, 3, 1, 2, 3]) == 3
assert longest_distinct_subarray([1, 1, 1, 1]) == 1
assert longest_distinct_subarray([1, 2, 3, 4, 5]) == 5
assert longest_distinct_subarray([]) == 0
print("Daily challenge complete! 🏆")

# %%
# Solution: Longest Distinct Subarray
def longest_distinct_subarray_solution(nums: list[int]) -> int:
    """O(n) time, O(n) space using Sliding Window and Set."""
    seen = set()
    left = 0
    max_len = 0
    
    for right in range(len(nums)):
        while nums[right] in seen:
            seen.remove(nums[left])
            left += 1
        seen.add(nums[right])
        max_len = max(max_len, right - left + 1)
        
    return max_len

# %% [markdown]
# ## 📝 Day 1 Review
#
# ### Patterns Learned Today
# - [ ] HashMap for O(1) lookups (Two Sum)
# - [ ] Frequency counting (Valid Anagram)
# - [ ] Prefix/Suffix products (Product Except Self)
# - [ ] Dynamic Array traversal
#
# ### Key Takeaways
# 1. When you need O(1) lookup → use a HashMap/Set.
# 2. When you can't use division → think prefix and suffix traversal.
# 3. Always consider: can I solve this in a single pass?
#
# ### Tomorrow's Preview
# **Day 02: HashMaps and Sets** — A deeper dive into hash-based data structures and their edge cases.
