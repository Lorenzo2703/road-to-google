# %% [markdown]
# # Day 07: Week 1 Review & Mock Interview
#
# **Week 1 — DSA Foundations**
#
# ---
#
# ## 📋 Week 1 Pattern Cheat Sheet
#
# | Pattern | When to Use | Key Problems |
# |---------|------------|-------------|
# | HashMap | O(1) lookup, counting, grouping | Two Sum, Group Anagrams |
# | Two Pointers | Sorted array pairs, partitioning | 3Sum, Container With Water |
# | Sliding Window | Subarray/substring with constraint | Min Window Substring |
# | Monotonic Stack | Next greater/smaller element | Daily Temperatures |
# | Fast/Slow Pointer | Cycle detection, find middle | Linked List Cycle |
# | Prefix Sum/Product | Range queries, cumulative ops | Product Except Self |
# | Kadane's | Maximum subarray | Maximum Subarray |
#
# ## 🎯 Mock Interview Instructions
#
# Set a timer. Solve each problem as if in a real interview:
# 1. **Clarify** the problem (2 min)
# 2. **Plan** your approach out loud (3 min)
# 3. **Code** the solution (15-20 min)
# 4. **Test** with examples (5 min)
# 5. **Analyze** time and space complexity

# %%
# MOCK PROBLEM 1 (25 minutes)
# LeetCode #560: Subarray Sum Equals K (Medium) — Google Tagged
# Given array nums and integer k, find total subarrays with sum = k

import time
start = time.time()

def subarray_sum(nums: list[int], k: int) -> int:
    # YOUR SOLUTION HERE — TIME YOURSELF!
    pass

# Don't look below until you've tried!









# Solution: Prefix sum + HashMap
def subarray_sum_sol(nums, k):
    count = 0
    prefix_sum = 0
    prefix_map = {0: 1}  # sum -> count of times seen
    for num in nums:
        prefix_sum += num
        if prefix_sum - k in prefix_map:
            count += prefix_map[prefix_sum - k]
        prefix_map[prefix_sum] = prefix_map.get(prefix_sum, 0) + 1
    return count

assert subarray_sum_sol([1,1,1], 2) == 2
assert subarray_sum_sol([1,2,3], 3) == 2
elapsed = time.time() - start
print(f'✅ Subarray Sum Equals K — Time: {elapsed:.1f}s')

# %%
# MOCK PROBLEM 2 (25 minutes)
# LeetCode #49: Group Anagrams (Medium) — Google Tagged
# Given a list of strings, group anagrams together

start = time.time()

def group_anagrams_mock(strs: list[str]) -> list[list[str]]:
    # YOUR SOLUTION HERE — TIME YOURSELF!
    pass

elapsed = time.time() - start
print(f'Mock Problem 2 — Time: {elapsed:.1f}s')
print('\nReview your solution against the Day 2 notebook.')

# %% [markdown]
# ## 📝 Week 1 Self-Assessment
#
# Rate yourself (1-5) on each area:
#
# | Area | Rating | Notes |
# |------|--------|-------|
# | Arrays & Strings | /5 | |
# | HashMaps & Sets | /5 | |
# | Two Pointers | /5 | |
# | Sliding Window | /5 | |
# | Stacks & Queues | /5 | |
# | Linked Lists | /5 | |
# | Problem-solving speed | /5 | |
# | Code cleanliness | /5 | |
#
# ### Areas to revisit before moving on:
# - [ ] _fill in based on your assessment_
#
# ### Ready for Week 2? ✅
# If you rated 3+ on all areas, move to Week 2.
# If any area is below 3, spend an extra day reviewing it.
