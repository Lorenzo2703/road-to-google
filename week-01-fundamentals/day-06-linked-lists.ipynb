# %% [markdown]
# # Day 06: Linked Lists
#
# **Week 1 — DSA Foundations**
#
# ---
#
# ## 📚 Theory
#
# ### Linked List Operations
# | Operation | Time |
# |-----------|------|
# | Access by index | O(n) |
# | Insert at head | O(1) |
# | Insert at tail | O(1) with tail pointer |
# | Delete | O(1) if you have the node |
# | Search | O(n) |
#
# ### Key Patterns
# 1. **Fast/Slow pointers**: Cycle detection, finding middle
# 2. **Reversal**: In-place reversal of entire list or portion
# 3. **Dummy head**: Simplifies edge cases for insertion/deletion
# 4. **Merge**: Combining sorted lists

# %%
# ListNode definition
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def to_list(head):
    result = []
    while head:
        result.append(head.val)
        head = head.next
    return result

def from_list(arr):
    dummy = ListNode(0)
    curr = dummy
    for val in arr:
        curr.next = ListNode(val)
        curr = curr.next
    return dummy.next

print('ListNode helpers loaded ✅')

# %%
# Problem 1: Reverse Linked List (Easy) — LC #206

def reverse_list(head: ListNode) -> ListNode:
    prev = None
    curr = head
    while curr:
        nxt = curr.next
        curr.next = prev
        prev = curr
        curr = nxt
    return prev

assert to_list(reverse_list(from_list([1,2,3,4,5]))) == [5,4,3,2,1]
print('✅ Reverse Linked List')

# %%
# Problem 2: Merge Two Sorted Lists (Easy) — LC #21

def merge_two_lists(l1: ListNode, l2: ListNode) -> ListNode:
    dummy = ListNode(0)
    curr = dummy
    while l1 and l2:
        if l1.val <= l2.val:
            curr.next = l1
            l1 = l1.next
        else:
            curr.next = l2
            l2 = l2.next
        curr = curr.next
    curr.next = l1 or l2
    return dummy.next

result = merge_two_lists(from_list([1,2,4]), from_list([1,3,4]))
assert to_list(result) == [1,1,2,3,4,4]
print('✅ Merge Two Sorted Lists')

# %%
# Problem 3: Linked List Cycle (Easy) — LC #141

def has_cycle(head: ListNode) -> bool:
    slow = fast = head
    while fast and fast.next:
        slow = slow.next
        fast = fast.next.next
        if slow == fast:
            return True
    return False

# Create cycle for testing
node1 = ListNode(3)
node2 = ListNode(2)
node3 = ListNode(0)
node4 = ListNode(-4)
node1.next = node2; node2.next = node3; node3.next = node4; node4.next = node2
assert has_cycle(node1) == True
assert has_cycle(from_list([1,2,3])) == False
print('✅ Linked List Cycle')

# %%
# Problem 4: Reorder List (Medium) — LC #143
# 1->2->3->4->5 becomes 1->5->2->4->3

def reorder_list(head: ListNode) -> None:
    if not head or not head.next: return
    # Step 1: Find middle
    slow = fast = head
    while fast.next and fast.next.next:
        slow = slow.next
        fast = fast.next.next
    # Step 2: Reverse second half
    prev, curr = None, slow.next
    slow.next = None
    while curr:
        nxt = curr.next
        curr.next = prev
        prev = curr
        curr = nxt
    # Step 3: Merge two halves
    first, second = head, prev
    while second:
        tmp1, tmp2 = first.next, second.next
        first.next = second
        second.next = tmp1
        first, second = tmp1, tmp2

lst = from_list([1,2,3,4,5])
reorder_list(lst)
assert to_list(lst) == [1,5,2,4,3]
print('✅ Reorder List')

# %%
# Problem 5: Remove Nth Node From End (Medium) — LC #19

def remove_nth_from_end(head: ListNode, n: int) -> ListNode:
    dummy = ListNode(0, head)
    left = dummy
    right = head
    # Advance right by n steps
    for _ in range(n):
        right = right.next
    # Move both until right reaches end
    while right:
        left = left.next
        right = right.next
    # Remove the node
    left.next = left.next.next
    return dummy.next

assert to_list(remove_nth_from_end(from_list([1,2,3,4,5]), 2)) == [1,2,3,5]
print('✅ Remove Nth From End')

# %% [markdown]
# ## 📝 Day 6 Review
# - [ ] In-place reversal pattern
# - [ ] Fast/slow pointer for middle and cycle detection
# - [ ] Dummy head to simplify edge cases
# - [ ] Two-pointer gap technique (remove Nth from end)
#
# ### Tomorrow: Week 1 Review & Mock Interview
