# %% [markdown]
# # Day 11: Heaps & Priority Queues
#
# **Week 2 — Intermediate DSA**
#
# ---
#
# ## 📚 Theory
#
# Heaps are used to keep track of the K largest or smallest elements.
#
# Python `heapq` module:
# - `heapq.heapify(arr)`
# - `heapq.heappush(heap, val)`
# - `heapq.heappop(heap)`
#
# Remember: Python's heapq is a MIN HEAP by default.

# %% [markdown]
# ## 🔨 Practice Problems

# %% [markdown]
# ### Problem 1: Kth Largest Element in an Array
#
# Find the kth largest element in an unsorted array.

# %%
import heapq

class Solution:
    def findKthLargest(self, nums: list[int], k: int) -> int:
        pass

# %% [markdown]
# ### Problem 2: Top K Frequent Elements
#
# Given an integer array nums and an integer k, return the k most frequent elements.

# %%
class Solution:
    def topKFrequent(self, nums: list[int], k: int) -> list[int]:
        pass

# %% [markdown]
# ## 📝 Day 11 Review
#
# - [ ] Understand the core concepts of today's theory
# - [ ] Complete all practice problems
# - [ ] Review optimal solutions and time/space complexities
