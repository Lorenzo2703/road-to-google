# %% [markdown]
# # Day 14: Review & Mock (Week 2)
#
# **Week 2 — Intermediate DSA**
#
# ---
#
# ## 📚 Theory
#
# Review week 2 topics: Trees, Heaps, Backtracking, Sorting, Binary Search.
# Perform a 45-minute timed mock interview.

# %% [markdown]
# ## 🔨 Practice Problems

# %% [markdown]
# ### Problem 1: Task Scheduler
#
# Given a characters array tasks and an integer n, find the least number of units of times that the CPU will take to finish all the given tasks.

# %%
class Solution:
    def leastInterval(self, tasks: list[str], n: int) -> int:
        pass

# %% [markdown]
# ## 📝 Day 14 Review
#
# - [ ] Understand the core concepts of today's theory
# - [ ] Complete all practice problems
# - [ ] Review optimal solutions and time/space complexities
