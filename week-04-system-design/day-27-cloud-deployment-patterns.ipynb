# %% [markdown]
# # Day 27: Cloud Deployment Patterns
#
# **Week 4 — System Design**
#
# ---
#
# ## 📚 Theory
#
# Deploying on GCP/AWS:
# - Docker and Kubernetes
# - Serverless (Cloud Run, Lambda)
# - CI/CD Pipelines
# - Blue/Green and Canary Deployments

# %% [markdown]
# ## 🧠 Exercises / Discussion

# %% [markdown]
# ### Deploying an Agent Application
#
# Discuss the architecture for deploying a scalable, highly available agent API on Google Cloud Platform.

# %% [markdown]
# ## 📝 Day 27 Review
#
# - [ ] Understand the core concepts of today's theory
# - [ ] Complete all practice problems
# - [ ] Review optimal solutions and time/space complexities
