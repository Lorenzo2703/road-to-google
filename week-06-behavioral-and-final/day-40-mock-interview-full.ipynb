# %% [markdown]
# # Day 40: Mock Interview Full
#
# **Week 6 — Behavioral & Final**
#
# ---
#
# ## 📚 Theory
#
# Simulate a full Google onsite loop:
# 1. Coding (45m)
# 2. Coding (45m)
# 3. System Design (45m)
# 4. Behavioral / Leadership (45m)

# %% [markdown]
# ## 🧠 Exercises / Discussion

# %% [markdown]
# ### Execute Mock Loop
#
# Find a friend or use an AI interviewer to do a full 4-hour simulation.

# %% [markdown]
# ## 📝 Day 40 Review
#
# - [ ] Understand the core concepts of today's theory
# - [ ] Complete all practice problems
# - [ ] Review optimal solutions and time/space complexities
