# %% [markdown]
# # Day 36: Behavioral Interview Prep
#
# **Week 6 — Behavioral & Final**
#
# ---
#
# ## 📚 Theory
#
# The STAR Method:
# - Situation: Set the scene
# - Task: What was the goal or problem?
# - Action: What did YOU do?
# - Result: What was the outcome? (Metrics matter)

# %% [markdown]
# ## 🧠 Exercises / Discussion

# %% [markdown]
# ### Draft 3 STAR Stories
#
# 1. A time you solved a complex technical problem.
# 2. A time you had a conflict with a coworker.
# 3. A time you had to learn a new technology quickly.

# %% [markdown]
# ## 📝 Day 36 Review
#
# - [ ] Understand the core concepts of today's theory
# - [ ] Complete all practice problems
# - [ ] Review optimal solutions and time/space complexities
