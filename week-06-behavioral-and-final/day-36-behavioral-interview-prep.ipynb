# %% [markdown]
# # Day 36: Behavioral Interview Prep
#
# **Week 6 — Behavioral & Final**
#
# ---
#
# ## 📚 Theory
#
# Add theoretical concepts here.

# %% [markdown]
# ## 📝 Day 36 Review
#
# - [ ] Concept 1
# - [ ] Concept 2
