# %% [markdown]
# # Day 39: Coding Final (Hard)
#
# **Week 6 — Behavioral & Final**
#
# ---
#
# ## 📚 Theory
#
# Tackling Leetcode Hard problems. Don't panic, break it down, talk out loud.

# %% [markdown]
# ## 🔨 Practice Problems

# %% [markdown]
# ### Problem 1: Word Search II
#
# Given an m x n board of characters and a list of strings words, return all words on the board.

# %%
class Solution:
    def findWords(self, board: list[list[str]], words: list[str]) -> list[str]:
        pass

# %% [markdown]
# ## 📝 Day 39 Review
#
# - [ ] Understand the core concepts of today's theory
# - [ ] Complete all practice problems
# - [ ] Review optimal solutions and time/space complexities
