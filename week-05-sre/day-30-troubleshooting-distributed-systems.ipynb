# %% [markdown]
# # Day 30: Troubleshooting Distributed Systems
#
# **Week 5 — SRE & Systems**
#
# ---
#
# ## 📚 Theory
#
# Diagnosing complex systems issues.
# - Network sockets, TCP states (TIME_WAIT, ESTABLISHED).
# - Debugging tools: strace, lsof, tcpdump, ss.
# - Saturated resources and troubleshooting workflows.

# %% [markdown]
# ## 🔨 Practice Problems

# %% [markdown]
# ### Problem 1: Web Log Analyzer
#
# Parse a large web server log to find client IPs encountering high latency or 5xx errors.

# %%
def analyze_logs(log_lines: list[str], response_time_threshold=1000) -> dict:
    # Parse logs and return IPs with high latency/errors
    pass

# %% [markdown]
# ## 📝 Day 30 Review
#
# - [ ] Understand the core concepts of today's theory
# - [ ] Complete all practice problems
# - [ ] Review optimal solutions and time/space complexities
