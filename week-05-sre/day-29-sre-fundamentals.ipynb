# %% [markdown]
# # Day 29: SRE Fundamentals & Systems Internals
#
# **Week 5 — SRE & Systems**
#
# ---
#
# ## 📚 Theory
#
# SRE and Systems Internals.
# - Processes, CPU scheduling, fork/exec, zombies.
# - Memory management, Swap, Page Faults, OOM Killer.
# - Linux namespaces, cgroups, container isolation.

# %% [markdown]
# ## 🔨 Practice Problems

# %% [markdown]
# ### Problem 1: System Resource Tracker
#
# Write a script that monitors CPU and RAM thresholds and logs warning alerts when exceeded.

# %%
class ResourceMonitor:
    def __init__(self, cpu_threshold=80.0, mem_threshold=80.0):
        self.cpu_threshold = cpu_threshold
        self.mem_threshold = mem_threshold
    def check_resources(self, current_cpu: float, current_mem: float) -> list[str]:
        # Return list of alerts
        pass

# %% [markdown]
# ## 📝 Day 29 Review
#
# - [ ] Understand the core concepts of today's theory
# - [ ] Complete all practice problems
# - [ ] Review optimal solutions and time/space complexities
