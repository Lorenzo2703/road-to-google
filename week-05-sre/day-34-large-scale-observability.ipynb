# %% [markdown]
# # Day 34: Large-scale Observability & Monitoring
#
# **Week 5 — SRE & Systems**
#
# ---
#
# ## 📚 Theory
#
# Designing metrics and logging pipelines.
# - Push vs pull metrics model, Prometheus metric format.
# - Symptom-based vs cause-based alerts, avoiding alert fatigue.

# %% [markdown]
# ## 🔨 Practice Problems

# %% [markdown]
# ### Problem 1: Symptom-based Alert Evaluator
#
# Evaluate error rates and latency to determine if an alert should be triggered.

# %%
def evaluate_alert(error_rate: float, p95_latency: float, error_threshold=0.01, latency_threshold=500.0) -> bool:
    # Return True if symptom alert should fire
    pass

# %% [markdown]
# ## 📝 Day 34 Review
#
# - [ ] Understand the core concepts of today's theory
# - [ ] Complete all practice problems
# - [ ] Review optimal solutions and time/space complexities
