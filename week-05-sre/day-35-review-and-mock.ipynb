# %% [markdown]
# # Day 35: Review & SRE Mock
#
# **Week 5 — SRE & Systems**
#
# ---
#
# ## 📚 Theory
#
# Review systems reliability concepts.
# - Google SRE book highlights.
# - Practice Nines calculation and systems design questions.

# %% [markdown]
# ## 🔨 Practice Problems

# %% [markdown]
# ### Problem 1: Error Budget Calculations
#
# Calculate allowed downtime in minutes and seconds based on a given SLO percentage over a 30-day window.

# %%
def calculate_downtime_budget(slo_pct: float) -> float:
    # Return allowed downtime in minutes
    pass

# %% [markdown]
# ## 📝 Day 35 Review
#
# - [ ] Understand the core concepts of today's theory
# - [ ] Complete all practice problems
# - [ ] Review optimal solutions and time/space complexities
