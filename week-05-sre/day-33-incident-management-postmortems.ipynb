# %% [markdown]
# # Day 33: Incident Management & Post-Mortems
#
# **Week 5 — SRE & Systems**
#
# ---
#
# ## 📚 Theory
#
# Responding to outages.
# - Incident response lifecycle: Triage, Mitigate, Resolve.
# - Post-Mortems: Blameless reviews, 5 Whys Root Cause Analysis.

# %% [markdown]
# ## 🔨 Practice Problems

# %% [markdown]
# ### Problem 1: Incident Severity Classifier
#
# Classify incident severity based on user impact percentages and system criticality.

# %%
def classify_incident(user_impact_pct: float, is_critical_service: bool) -> str:
    # Return SEV-1, SEV-2, or SEV-3
    pass

# %% [markdown]
# ## 📝 Day 33 Review
#
# - [ ] Understand the core concepts of today's theory
# - [ ] Complete all practice problems
# - [ ] Review optimal solutions and time/space complexities
