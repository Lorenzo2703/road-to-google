# %% [markdown]
# # Day 32: Automating Infrastructure
#
# **Week 5 — SRE & Systems**
#
# ---
#
# ## 📚 Theory
#
# Infrastructure as Code and Automation.
# - Terraform configuration patterns.
# - Kubernetes Pods, Services, Ingress, Deployments, Custom Operators.
# - Automation of toil (repetitive operations).

# %% [markdown]
# ## 🔨 Practice Problems

# %% [markdown]
# ### Problem 1: Kubernetes Resource Config Generator
#
# Write a function that generates a Kubernetes deployment YAML with resource constraints and health probes.

# %%
def generate_k8s_deployment(name: str, image: str, cpu_limit="500m", mem_limit="512Mi") -> str:
    # Return deployment YAML
    pass

# %% [markdown]
# ## 📝 Day 32 Review
#
# - [ ] Understand the core concepts of today's theory
# - [ ] Complete all practice problems
# - [ ] Review optimal solutions and time/space complexities
