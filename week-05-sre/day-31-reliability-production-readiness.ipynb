# %% [markdown]
# # Day 31: Reliability & Production Readiness
#
# **Week 5 — SRE & Systems**
#
# ---
#
# ## 📚 Theory
#
# Guaranteeing system reliability.
# - SLIs, SLOs, SLAs, and Error Budgets.
# - Fault-tolerant patterns: Circuit Breakers, retries with exponential backoff and jitter.

# %% [markdown]
# ## 🔨 Practice Problems

# %% [markdown]
# ### Problem 1: Retry Policy with Jitter
#
# Implement a retry helper function with exponential backoff and random jitter to avoid thundering herds.

# %%
import time
import random

def retry_with_jitter(func, max_retries=3, base_delay=1.0):
    # Execute func with retry policy and jitter
    pass

# %% [markdown]
# ## 📝 Day 31 Review
#
# - [ ] Understand the core concepts of today's theory
# - [ ] Complete all practice problems
# - [ ] Review optimal solutions and time/space complexities
